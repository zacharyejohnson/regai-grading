# %%
import pandas as pd
import numpy as np
import requests
import json
from tqdm import tqdm
from scipy import stats

df = pd.read_excel('data/asap-aes/training_set_rel3.xlsx')

df_sample = df[df["essay_set"] == 1][0:1]

API_BASE_URL = "http://localhost:8000/api"

import time

def create_submission(essay, assignment_id):
    response = requests.post(f"{API_BASE_URL}/submissions/submit_text/", json={
        "content": essay,
        "assignment": assignment_id, 
        "student_name": "Anonymous"
    })
    if response.status_code != 201:
        print(f"Error creating submission: {response.status_code}")
        print(f"Response content: {response.text}")
        return None
    return response.json()
    
import time

def process_submissions(df_sample, assignment_id):
    system_grades = []
    submission_ids = []
    
    for _, row in tqdm(df_sample.iterrows(), total=len(df_sample)):
        # Create submission
        submission = create_submission(row['essay'], assignment_id)
        if submission is None:
            continue
        
        # Print submission response for debugging
        print(f"Submission response: {submission}")
        
        # Check if 'id' is in the response, if not, use an alternative field or skip
        if 'id' in submission:
            submission_id = submission['id']
        else:
            print(f"Unable to find submission ID in response: {submission}")
            continue
        
        submission_ids.append(submission_id)
        
        # Wait for grading to complete and get results
        max_attempts = 20
        attempt = 0
        while attempt < max_attempts:
            result = get_grading_results(submission_id)
            print("RESULT", result)
            if result['status'] == 'graded':
                system_grades.append(result['overall_score'])
                break
            time.sleep(10)  # Wait for 10 seconds before checking again
            attempt += 1
        
        if attempt == max_attempts:
            print(f"Grading not completed for submission {submission_id} after {max_attempts} attempts")
            system_grades.append(None)
    
    return submission_ids, system_grades

def get_grading_results(submission_id):
    response = requests.get(f"{API_BASE_URL}/submissions/{submission_id}/")
    data = response.json()
    
    # Print the full response for debugging
    print(f"Full API response for submission {submission_id}:")
    print(json.dumps(data, indent=2))
    
    if data.get('status') == 'graded' and 'category_scores' in data:
        category_scores = data['category_scores']
        
        if category_scores and isinstance(category_scores[0], dict) and 'categories' in category_scores[0]:
            categories = category_scores[0]['categories']
            
            valid_scores = [cat['score'] for cat in categories if isinstance(cat.get('score'), (int, float))]
            
            if valid_scores:
                overall_score = sum(valid_scores) / len(valid_scores)
                return {
                    'status': 'graded',
                    'overall_score': overall_score / 6  # Assuming the max score is 6
                }
    
    # If we couldn't extract a valid score or the submission is not graded
    return {
        'status': 'pending',
        'overall_score': None
    }
    
assignment_id = 9
try:
    submission_ids, system_grades = process_submissions(df_sample, assignment_id)

    # Create a DataFrame with all grades
    comparison_df = pd.DataFrame({
        'Submission ID': submission_ids,
        'Rater1 Grade': df_sample['rater1_domain1'].values[:len(submission_ids)] / 6,
        'Rater2 Grade': df_sample['rater2_domain1'].values[:len(submission_ids)] / 6,
        'System Grade': system_grades
    })

    # Print out the first few rows of the DataFrame for verification
    print("\nFirst few rows of the comparison DataFrame:")
    print(comparison_df.head())

except Exception as e:
    print(f"An error occurred: {str(e)}")

# Calculate correlations
def calculate_correlations(df):
    correlations = {}
    for col1 in ['Rater1 Grade', 'Rater2 Grade', 'System Grade']:
        for col2 in ['Rater1 Grade', 'Rater2 Grade', 'System Grade']:
            if col1 != col2:
                mask = ~np.isnan(df[col1]) & ~np.isnan(df[col2])
                pearson, _ = stats.pearsonr(df[col1][mask], df[col2][mask])
                spearman, _ = stats.spearmanr(df[col1][mask], df[col2][mask])
                correlations[f"{col1} vs {col2}"] = {
                    'Pearson': pearson,
                    'Spearman': spearman
                }
    return correlations

correlations = calculate_correlations(comparison_df)
print("Correlations:")
print(json.dumps(correlations, indent=2))

# Calculate and print mean absolute error
def calculate_mae(df):
    mae = {}
    for col1 in ['Rater1 Grade', 'Rater2 Grade', 'System Grade']:
        for col2 in ['Rater1 Grade', 'Rater2 Grade', 'System Grade']:
            if col1 != col2:
                mask = ~np.isnan(df[col1]) & ~np.isnan(df[col2])
                mae[f"{col1} vs {col2}"] = np.mean(np.abs(df[col1][mask] - df[col2][mask]))
    return mae

mae = calculate_mae(comparison_df)
print("\nMean Absolute Error:")
print(json.dumps(mae, indent=2))

# Print summary statistics
print("\nSummary Statistics:")
print(comparison_df.describe())

# Print percentage of null values
print("\nPercentage of null values:")
print(comparison_df.isnull().mean() * 100)

# # Function to get knowledge base items
# def get_knowledge_base_items():
#     response = requests.get(f"{API_BASE_URL}/knowledge-base/")
#     return response.json()

# # Analyze knowledge base items
# kb_items = get_knowledge_base_items()
# unapproved_items = [item for item in kb_items if item['status'] == 'pending']

# print(f"\nNumber of unapproved knowledge base items created: {len(unapproved_items)}")

# # Display some unapproved items for verification
# print("Sample unapproved knowledge base items:")
# for item in unapproved_items[:5]:  # Display first 5 items
#     print(json.dumps(item, indent=3))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Submission response: {'id': 1207, 'assignment': 9, 'student_name': 'Anonymous', 'content': "Dear local newspaper, I think effects computers have on people are great learning skills/affects because they give us time to chat with friends/new people, helps us learn about the globe(astronomy) and keeps us out of troble! Thing about! Dont you think so? How would you feel if your teenager is always on the phone with friends! Do you ever time to chat with your friends or buisness partner about things. Well now - there's a new way to chat the computer, theirs plenty of sites on the internet to do so: @ORGANIZATION1, @ORGANIZATION2, @CAPS1, facebook, myspace ect. Just think now while your setting up meeting with your boss on the computer, your teenager is having fun on the phone not rushing to get off cause you want to use it. How did you learn about other countrys/states outside of yours? Well I have by computer/internet, it's a new way to learn about what going on in our time! You might think your child spends a lot of time on the computer, but ask them so question about the economy, sea floor spreading or even about the @DATE1's you'll be surprise at how much he/she knows. Believe it or not the computer is much interesting then in class all day reading out of books. If your child is home on your computer or at a local library, it's better than being out with friends being fresh, or being perpressured to doing something they know isnt right. You might not know where your child is, @CAPS2 forbidde in a hospital bed because of a drive-by. Rather than your child on the computer learning, chatting or just playing games, safe and sound in your home or community place. Now I hope you have reached a point to understand and agree with me, because computers can have great effects on you or child because it gives us time to chat with friends/new people, helps us learn about the globe and believe or not keeps us out of troble. Thank you for listening.", 'file': None, 'submitted_at': '2024-07-19T16:59:31.805478Z', 'status': 'queued', 'overall_score': None, 'category_scores': None, 'grading_critique': None, 'graded_at': None, 'grades': []}
# Full API response for submission 1207:
# {
#   "id": 1207,
#   "assignment": 9,
#   "student_name": "Anonymous",
#   "content": "Dear local newspaper, I think effects computers have on people are great learning skills/affects because they give us time to chat with friends/new people, helps us learn about the globe(astronomy) and keeps us out of troble! Thing about! Dont you think so? How would you feel if your teenager is always on the phone with friends! Do you ever time to chat with your friends or buisness partner about things. Well now - there's a new way to chat the computer, theirs plenty of sites on the internet to do so: @ORGANIZATION1, @ORGANIZATION2, @CAPS1, facebook, myspace ect. Just think now while your setting up meeting with your boss on the computer, your teenager is having fun on the phone not rushing to get off cause you want to use it. How did you learn about other countrys/states outside of yours? Well I have by computer/internet, it's a new way to learn about what going on in our time! You might think your child spends a lot of time on the computer, but ask them so question about the economy, sea floor spreading or even about the @DATE1's you'll be surprise at how much he/she knows. Believe it or not the computer is much interesting then in class all day reading out of books. If your child is home on your computer or at a local library, it's better than being out with friends being fresh, or being perpressured to doing something they know isnt right. You might not know where your child is, @CAPS2 forbidde in a hospital bed because of a drive-by. Rather than your child on the computer learning, chatting or just playing games, safe and sound in your home or community place. Now I hope you have reached a point to understand and agree with me, because computers can have great effects on you or child because it gives us time to chat with friends/new people, helps us learn about the globe and believe or not keeps us out of troble. Thank you for listening.",
#   "file": null,
#   "submitted_at": "2024-07-19T16:59:31.805478Z",
#   "status": "graded",
#   "overall_score": 0.0,
#   "category_scores": [
#     {
#       "categories": [
#         {
#           "name": "Argument Development and Support",
#           "score": 3,
#           "justification": "The submission continues to merit a score of 3 in this category. It presents a discernible position with basic support, discussing the benefits of computers in terms of chatting with friends/new people, learning about the globe, and staying out of trouble. However, the reasons lack depth and the examples provided are not fully developed, aligning with the level 3 description in the rubric."
#         },
#         {
#           "name": "Organization and Coherence",
#           "score": 2,
#           "justification": "The score of 2 remains appropriate for this category. The submission still exhibits minimal organization with jumbled ideas within paragraphs, unclear introduction and conclusion, and a lack of transitions. These aspects align well with the characteristics outlined in the level 2 description of the rubric."
#         },
#         {
#           "name": "Language Use and Style",
#           "score": 2,
#           "justification": "Maintaining a score of 2 in this category is supported by the continued use of basic vocabulary with numerous errors in grammar, spelling, and punctuation. The simplistic sentence structure and absence of personal style are evident, aligning with the level 2 criteria in the rubric."
#         },
#         {
#           "name": "Audience Awareness and Persuasive Techniques",
#           "score": 3,
#           "justification": "The score of 3 remains fitting for this category. While some awareness of the audience is demonstrated in the submission, the use of persuasive techniques is inconsistent. The tone, although generally suitable for a newspaper letter, could benefit from being more engaging and persuasive, as outlined in the level 3 description of the rubric."
#         }
#       ]
#     }
#   ],
#   "grading_critique": {
#     "overall_assessment": "The grader has accurately evaluated the submission based on the rubric criteria. The grades are aligned with the specific details mentioned in the rubric for each category.",
#     "category_critiques": [
#       {
#         "category": "Argument Development and Support",
#         "critique": "The submission rightfully received a score of 3 in this category as it presents a discernible position with basic support. The reasons provided lack depth and the examples are not fully developed, which aligns with the level 3 description in the rubric."
#       },
#       {
#         "category": "Organization and Coherence",
#         "critique": "The score of 2 in this category is appropriate as the submission shows minimal organization. The ideas within paragraphs are jumbled, the introduction and conclusion are unclear, and there is a lack of transitions, all matching the level 2 description in the rubric."
#       },
#       {
#         "category": "Language Use and Style",
#         "critique": "The score of 2 in this category is well-justified. The submission uses basic vocabulary with numerous errors in grammar, spelling, and punctuation, hindering understanding. The simplistic sentence structure and lack of personal style align with the level 2 description in the rubric."
#       },
#       {
#         "category": "Audience Awareness and Persuasive Techniques",
#         "critique": "The score of 3 is fitting as there is some awareness of the audience. The writer attempts basic persuasive techniques inconsistently. While the tone is generally appropriate for a newspaper letter, it could be more engaging and persuasive, aligning with the level 3 description in the rubric."
#       }
#     ],
#     "potential_biases": [],
#     "suggestions_for_improvement": []
#   },
#   "graded_at": "2024-07-19T16:59:47.433653Z",
#   "grades": []
# }
# RESULT {'status': 'pending', 'overall_score': None}
#   0%|          | 0/1 [00:29<?, ?it/s]
#
# KeyboardInterrupt

# %%
comparison_df = comparison_df[comparison_df["System Grade"] != 0]

# %%
comparison_df
# Out:
#    Submission ID  Rater1 Grade  Rater2 Grade  System Grade
# 0           1191      0.833333      0.666667      0.500000
# 2           1193      0.666667      0.666667      0.333333
# 5           1196      0.500000      0.500000      0.666667
# 9           1200      0.333333      0.333333      0.166667

# %%
mae = calculate_mae(comparison_df)
print("\nMean Absolute Error:")
print(json.dumps(mae, indent=2))

# Print summary statistics
print("\nSummary Statistics:")
print(comparison_df.describe())

# Print percentage of null values
print("\nPercentage of null values:")
print(comparison_df.isnull().mean() * 100)
# Out:
# Mean Absolute Error:
# {
#   "Rater1 Grade vs Rater2 Grade": 0.0,
#   "Rater1 Grade vs System Grade": 5.551115123125783e-17,
#   "Rater2 Grade vs Rater1 Grade": 0.0,
#   "Rater2 Grade vs System Grade": 5.551115123125783e-17,
#   "System Grade vs Rater1 Grade": 5.551115123125783e-17,
#   "System Grade vs Rater2 Grade": 5.551115123125783e-17
# }
#
# Summary Statistics:
#        Submission ID  Rater1 Grade  Rater2 Grade  System Grade
# count       3.000000      3.000000      3.000000      3.000000
# mean     1175.666667      0.500000      0.500000      0.500000
# std         2.516611      0.166667      0.166667      0.166667
# min      1173.000000      0.333333      0.333333      0.333333
# 25%      1174.500000      0.416667      0.416667      0.416667
# 50%      1176.000000      0.500000      0.500000      0.500000
# 75%      1177.000000      0.583333      0.583333      0.583333
# max      1178.000000      0.666667      0.666667      0.666667
#
# Percentage of null values:
# Submission ID    0.0
# Rater1 Grade     0.0
# Rater2 Grade     0.0
# System Grade     0.0
# dtype: float64

# %%
correlations = calculate_correlations(comparison_df)
print("Correlations:")
print(json.dumps(correlations, indent=2))
# Out:
# Correlations:
# {
#   "Rater1 Grade vs Rater2 Grade": {
#     "Pearson": 0.9999999999999999,
#     "Spearman": 1.0
#   },
#   "Rater1 Grade vs System Grade": {
#     "Pearson": 1.0,
#     "Spearman": 1.0
#   },
#   "Rater2 Grade vs Rater1 Grade": {
#     "Pearson": 0.9999999999999999,
#     "Spearman": 1.0
#   },
#   "Rater2 Grade vs System Grade": {
#     "Pearson": 1.0,
#     "Spearman": 1.0
#   },
#   "System Grade vs Rater1 Grade": {
#     "Pearson": 1.0,
#     "Spearman": 1.0
#   },
#   "System Grade vs Rater2 Grade": {
#     "Pearson": 1.0,
#     "Spearman": 1.0
#   }
# }

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[183], line 1
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,8))
comparison_df[["Rater1 Grade", "Rater2 Grade", "System Grade"]].hist(ax=ax)
# Out:
# C:\Users\NDSU-Prof\AppData\Local\Temp\ipykernel_13568\2189312810.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   comparison_df[["Rater1 Grade", "Rater2 Grade", "System Grade"]].hist(ax=ax)
# array([[<Axes: title={'center': 'Rater1 Grade'}>,
#         <Axes: title={'center': 'Rater2 Grade'}>],
#        [<Axes: title={'center': 'System Grade'}>, <Axes: >]], dtype=object)

# %%
submission_ids
# Out:
# [1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179]

# %%
comparison_df.to_excel('ratings_comparison_withrubric_andcritic_withknowledgebase1.xlsx')

# %%
pd.DataFrame.from_dict(correlations).to_excel('correlations_withrubric_andcritic_withknowledgebase1.xlsx')

# %%
comparison_df.describe().to_excel('summary_stats_withrubric_andcritic_withknowledgebase1.xlsx')

# %%
API_BASE_URL = "http://localhost:8000/api"

# %%
# Backend API URL
API_URL = "http://localhost:8000/api"

# %%
def fetch_submissions_with_cycles(assignment_id):
    response = requests.get(f"{API_BASE_URL}/submissions/with_knowledge_base_items/?assignment={assignment_id}")
    return response.json()

def normalize_score(score, min_score, max_score):
    return (score - min_score) / (max_score - min_score)

# %%
# Function to create a submission
def create_submission(essay):
    response = requests.post(f"{API_URL}/submissions/", json={
        "content": essay,
        "assignment": 22, 
        "student_name": "Anonymous"
    })
    return response.json()

# %%
# Function to get grading results
def get_grading_results(submission_id):
    response = requests.get(f"{API_URL}/submissions/{submission_id}/")
    return response.json()

# %%
# Function to get knowledge base items
def get_knowledge_base_items():
    response = requests.get(f"{API_URL}/knowledge-base/")
    return response.json()

# %%
assignment_id = 22  # Replace with the correct assignment ID
submissions_data = fetch_submissions_with_cycles(assignment_id)

# Process the data
processed_data = []
for submission in submissions_data:
    rater1_grade = submission.get('rater1_domain1')
    rater2_grade = submission.get('rater2_domain1')
    system_grade = submission.get('overall_score')
    
    if rater1_grade is not None:
        rater1_grade = normalize_score(rater1_grade, 0, 5)  # Assuming original scale is 0-5
    if rater2_grade is not None:
        rater2_grade = normalize_score(rater2_grade, 0, 5)  # Assuming original scale is 0-5
    
    processed_data.append({
        'Submission ID': submission['id'],
        'Rater1 Grade': rater1_grade,
        'Rater2 Grade': rater2_grade,
        'System Grade': system_grade
    })

comparison_df = pd.DataFrame(processed_data)

# %%
comparison_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def calculate_correlations(df):
    correlations = {}
    for col1 in ['Rater1 Grade', 'Rater2 Grade', 'System Grade']:
        for col2 in ['Rater1 Grade', 'Rater2 Grade', 'System Grade']:
            if col1 != col2:
                mask = ~np.isnan(df[col1]) & ~np.isnan(df[col2])
                pearson, _ = stats.pearsonr(df[col1][mask], df[col2][mask])
                spearman, _ = stats.spearmanr(df[col1][mask], df[col2][mask])
                correlations[f"{col1} vs {col2}"] = {
                    'Pearson': pearson,
                    'Spearman': spearman
                }
    return correlations

assignment_id = 22  # Replace with the correct assignment ID

response = requests.get(f"{API_URL}/assignments/{assignment_id}/")
assignment = response.json()
rubric = assignment['rubric']

# Calculate min and max scores based on the rubric
min_score = 1
max_score = len(rubric['categories']) + 1

# Function to normalize scores to 0-1 range
def normalize_score(score, min_score, max_score):
    return (score - min_score) / (max_score - min_score)

# Normalize Rater1 and Rater2 grades
comparison_df['Rater1 Grade Normalized'] = comparison_df['Rater1 Grade'].apply(lambda x: normalize_score(x, min_score, max_score))
comparison_df['Rater2 Grade Normalized'] = comparison_df['Rater2 Grade'].apply(lambda x: normalize_score(x, min_score, max_score))

# %%
comparison_df.sort_values(by="Rater1 Grade Normalized", ascending=False )
# Out:
#    Submission ID  Rater1 Grade  Rater2 Grade  System Grade  \
# 1            101           5.0           4.0      0.333333
# 3            103           5.0           5.0      0.500000
# 0            100           4.0           4.0      0.500000
# 2            102           4.0           3.0      0.333333
# 4            104           4.0           4.0      0.333333
#
#    Rater1 Grade Normalized  Rater2 Grade Normalized
# 1                      4.0                      3.0
# 3                      4.0                      4.0
# 0                      3.0                      3.0
# 2                      3.0                      2.0
# 4                      3.0                      3.0

# %%
correlations = calculate_correlations(comparison_df)
print("Correlations:")
print(json.dumps(correlations, indent=2))
# Out:
# Correlations:
# {
#   "Rater1 Grade vs Rater2 Grade": {
#     "Pearson": 0.6454972243679029,
#     "Spearman": 0.6454972243679028
#   },
#   "Rater1 Grade vs System Grade": {
#     "Pearson": -0.6344412685745155,
#     "Spearman": -0.6454972243679028
#   },
#   "Rater2 Grade vs Rater1 Grade": {
#     "Pearson": 0.6454972243679029,
#     "Spearman": 0.6454972243679028
#   },
#   "Rater2 Grade vs System Grade": {
#     "Pearson": 0.0,
#     "Spearman": 0.0
#   },
#   "System Grade vs Rater1 Grade": {
#     "Pearson": -0.6344412685745155,
#     "Spearman": -0.6454972243679028
#   },
#   "System Grade vs Rater2 Grade": {
#     "Pearson": 0.0,
#     "Spearman": 0.0
#   }
# }

# %%
# Calculate and print mean absolute error
def calculate_mae(df):
    mae = {}
    for col1 in ['Rater1 Grade', 'Rater2 Grade', 'System Grade']:
        for col2 in ['Rater1 Grade', 'Rater2 Grade', 'System Grade']:
            if col1 != col2:
                mask = ~np.isnan(df[col1]) & ~np.isnan(df[col2])
                mae[f"{col1} vs {col2}"] = np.mean(np.abs(df[col1][mask] - df[col2][mask]))
    return mae

mae = calculate_mae(comparison_df)
print("\nMean Absolute Error:")
print(json.dumps(mae, indent=2))
# Out:
# Mean Absolute Error:
# {
#   "Rater1 Grade vs Rater2 Grade": 0.4,
#   "Rater1 Grade vs System Grade": 4.106666666666667,
#   "Rater2 Grade vs Rater1 Grade": 0.4,
#   "Rater2 Grade vs System Grade": 3.9066666666666663,
#   "System Grade vs Rater1 Grade": 4.106666666666667,
#   "System Grade vs Rater2 Grade": 3.9066666666666663
# }

# %%
kb_items = get_knowledge_base_items()
unapproved_items = [kb_items[item] for item in kb_items]

print(f"\nNumber of unapproved knowledge base items created: {len(unapproved_items)}")

# Display some unapproved items for verification
print("Sample unapproved knowledge base items:")
for item in unapproved_items[:5]:  # Display first 5 items
    print(json.dumps(item, indent=3))

# Print summary statistics
print("\nSummary Statistics:")
print(comparison_df.describe())

# Print percentage of null values
print("\nPercentage of null values:")
print(comparison_df.isnull().mean() * 100)
# Out:
# Number of unapproved knowledge base items created: 4
# Sample unapproved knowledge base items:
# 23
# "http://localhost:8000/api/knowledge-base/?page=2"
# null
# [
#    {
#       "id": 29,
#       "item_type": "grade",
#       "content": {
#          "submission_id": 84,
#          "overall_score": 0.36666666666666664,
#          "category_scores": [
#             {
#                "name": "Position Clarity",
#                "score": 2,
#                "justification": "The author's position opposing the use of computers in society is somewhat clear but lacks focus and cohesion, in line with the rubric description for a score of 2. The arguments presented, such as concerns about obesity, cramps, sexual harassment, and cyberbullying, are valid but are conveyed in a disjointed and confusing manner. There is an overarching lack of emphasis and conviction, which makes the stance difficult to fully understand. Additionally, the narrative sometimes drifts off-topic, further complicating clarity. To align better with the rubric, the submission needs a more structured presentation and stronger articulation of its position."
#             },
#             {
#                "name": "Supporting Arguments",
#                "score": 3,
#                "justification": "The submission offers some supporting arguments, such as the risks of obesity, cramps, sexual harassment, and cyberbullying associated with computer usage. While there is a mix of general observations and specific examples, the depth of explanation and specific evidence, such as statistics and case studies, are insufficient. The points brought up are mostly supported but lack the level of detail necessary to be convincing and fully developed. According to the rubric, this aligns more closely with a score of 3, which indicates some supporting arguments with minimal elaboration."
#             },
#             {
#                "name": "Organization and Structure",
#                "score": 2,
#                "justification": "The submission demonstrates weak organization, aligning with the rubric's description for a score of 2. Despite having a basic structure with an introduction, body paragraphs, and a conclusion, the flow of ideas is disrupted by significant logical gaps and inconsistencies. Transitions between paragraphs are abrupt, resulting in a disjointed sequence of ideas. The arguments lack development, and there is a clear lack of coherence and clarity in the progression from one point to the next. Overall, these issues make it challenging to follow the author's line of reasoning and justify a score of 2."
#             },
#             {
#                "name": "Engagement and Audience Awareness",
#                "score": 2,
#                "justification": "The grade of 2 aligns with the rubric's criteria for showing minimal awareness of the audience and limited engagement. The submission makes an effort to address issues like obesity, cramps, sexual harassment, and cyberbullying, but these points are not well-developed and do not form a cohesive argument. The use of placeholders (e.g., @LOCATION1, @NUM1) disrupts the coherence of the text and makes it less engaging. Additionally, the hypothetical example of the child gaining weight lacks sufficient detail and emotional depth, failing to resonate with the reader. While there is some attempt to engage the reader directly in the concluding paragraph, this is insufficient to substantially elevate the overall engagement level. Therefore, the score of 2 is appropriate given the lack of depth and clarity required to engage the reader effectively."
#             },
#             {
#                "name": "Language and Style",
#                "score": 1,
#                "justification": "The submission demonstrates poor language use, aligning with the rubric's description for this level. There are frequent errors in grammar, syntax, and vocabulary, including inconsistent verb tenses, awkward phrasing, and incorrect use of conjunctions. Additionally, the text contains multiple spelling mistakes and incomplete thoughts. These pervasive issues significantly impair the readability and coherence of the argument presented, indicating a lack of proficiency in basic writing mechanics. The justification aligns closely with the rubric's criteria for a score of 1, emphasizing the frequent language errors and their impact on the overall quality of the submission."
#             }
#          ],
#          "critique": "{\n    \"overall_assessment\": \"The grading provided appears to be reasonably consistent with the rubric criteria. However, there are some areas where the justifications could be more aligned with the rubric descriptions, and some inconsistencies in scoring that need addressing.\",\n    \"category_critiques\": [\n        {\n            \"category\": \"Position Clarity\",\n            \"critique\": \"The score of 2 aligns with the rubric's description of a position that is 'somewhat clear but may lack focus or be stated in a confusing manner.' The justification accurately reflects this, citing the lack of focus and coherence, and the narrative's tendency to wander off-topic.\"\n        },\n        {\n            \"category\": \"Supporting Arguments\",\n            \"critique\": \"The score of 4 seems appropriate given the rubric\u2019s definition of 'adequate supporting arguments with a mix of general and specific details.' The justification that the explanations lack depth and specific evidence but are adequately supported aligns with the rubric. However, there is a slight discrepancy as the rubric for a score of 4 suggests the presence of 'mostly specific details,' which the justification indicates are lacking.\"\n        },\n        {\n            \"category\": \"Organization and Structure\",\n            \"critique\": \"The score of 2 is in line with the rubric's description of 'weak organization' where 'basic structure is present but ideas may lack logical flow.' The justification mentions significant logical gaps, abrupt transitions, and a disjointed sequence of ideas, which supports this score.\"\n        },\n        {\n            \"category\": \"Engagement and Audience Awareness\",\n            \"critique\": \"The score of 2 accurately reflects the rubric's criteria for 'minimal awareness of the audience' and 'limited engagement.' The justification notes the lack of developed points and sufficient detail to engage the reader, as well as the disruptive placeholders, which aligns with this scoring level.\"\n        },\n        {\n            \"category\": \"Language and Style\",\n            \"critique\": \"The score of 1 is consistent with the rubric's description of 'poor language use with frequent errors in grammar, syntax, and vocabulary.' The justification highlights numerous errors and issues that significantly impair readability and coherence, which is in agreement with this assessment.\"\n        }\n    ],\n    \"potential_biases\": [\n        \"There may be a subjective bias in evaluating the depth and persuasiveness of the supporting arguments.\",\n        \"Bias could also stem from the perceived disjointedness of the narrative, which may vary based on individual reading and interpretation.\"\n    ],\n    \"suggestions_for_improvement\": [\n        \"Ensure that justifications for scores provide clear examples directly tied to the rubric descriptions.\",\n        \"Clarify the expectations for the level of detail in supporting arguments to distinguish more clearly between different scoring levels.\",\n        \"Provide concrete suggestions for improving the organization and structure to help guide the author towards a more coherent presentation.\",\n        \"Avoid using placeholders in future submissions to maintain coherence and readability.\",\n        \"Proofread the submission to eliminate grammar and syntax errors, possibly using tools or peer reviews to catch mistakes.\"\n    ]\n}"
#       },
#       "status": "pending",
#       "created_at": "2024-07-08T14:53:42.601781Z",
#       "updated_at": "2024-07-08T14:53:42.601781Z",
#       "approved_by": null,
#       "approved_at": null,
#       "human_approved": false
#    },
#    {
#       "id": 28,
#       "item_type": "grade",
#       "content": {
#          "submission_id": 83,
#          "overall_score": 0.39166666666666666,
#          "category_scores": [
#             {
#                "name": "Position Clarity",
#                "score": 2,
#                "justification": "The position taken on the impact of computers on human life is somewhat clear, aligning with the rubric\u2019s description for a score of 2. However, it lacks focus and is presented in a confusing manner. The main idea is frequently interrupted by tangential points and hypothetical scenarios, which detracts from a coherent understanding. For example, the discussion veers off-topic when introducing unrelated hypothetical scenarios, making it difficult to follow the author's stance. Additionally, grammar and syntax issues, such as inconsistent tense usage and awkward sentence structure, further obscure the position's clarity. To improve, focus on clearly articulating the main position and ensuring that all supporting points directly relate to and reinforce this stance."
#             },
#             {
#                "name": "Supporting Arguments",
#                "score": 3,
#                "justification": "The submission provides some supporting arguments, particularly highlighting the utility of computers in shopping, communication, and entertainment. However, these arguments are generally broad and lack substantial specific details or evidence that would enhance their persuasiveness. For instance, while the submission mentions online shopping and email communication, it does not delve into detailed examples or statistics that could strengthen these points. The rubric specifies that a score of 3 is warranted when there are some supporting arguments with minimal elaboration, which is accurately reflected in the submission's general and vague explanations without specific details. To improve, the submission should include more detailed examples and evidence to substantiate the points made."
#             },
#             {
#                "name": "Organization and Structure",
#                "score": 2,
#                "justification": "The submission demonstrates weak organization, aligning with a score of 2 as per the rubric. While a basic structure with an introduction, body paragraphs, and a conclusion exists, the ideas within the paragraphs are disjointed and do not flow logically. Transitions between thoughts are abrupt, creating inconsistencies and redundancies throughout the text. To improve, clearer topic sentences and better linkage of ideas are essential. For instance, in the second paragraph, the transition from discussing the main argument to the supporting evidence is abrupt and lacks coherence, which disrupts the logical progression of ideas."
#             },
#             {
#                "name": "Engagement and Audience Awareness",
#                "score": 3,
#                "justification": "The submission demonstrates some awareness of the audience and makes an effort to engage the reader through rhetorical questions and relatable scenarios. For example, the scenario about needing groceries and being able to buy food online is a practical situation that many readers can relate to. Additionally, the piece touches on various ways computers have impacted daily life, which helps to sustain interest. However, the engagement is somewhat undermined by frequent grammatical errors, awkward phrasing, and incomplete thoughts, which can distract and disengage the reader. A detailed examination reveals that while certain parts engage effectively, like the grocery-buying example, other sections are less engaging due to the noted issues. Overall, it aligns with the criteria for 'Shows some awareness of the audience. Basic level of engagement.' in the rubric."
#             },
#             {
#                "name": "Language and Style",
#                "score": 1,
#                "justification": "The submission is marked by consistent and frequent errors in grammar, syntax, and vocabulary, which significantly detract from the overall readability and coherence of the text. Notable examples include incorrect phrases such as 'The most well know, is the computer' instead of 'The best known is the computer' and 'allows people do buy things online' instead of 'allows people to buy things online'. Additionally, the text contains multiple misspellings like 'ther' instead of 'there', 'dosen't' instead of 'doesn't', and 'adress' instead of 'address'. Furthermore, sentence structures are often awkward and unclear, exemplified by phrases like 'all these is to be in you on the computer' and 'these isn't or person who can't fled atleast our game enjoyable'. Due to these persistent issues, the overall writing lacks a consistent use of correct grammar and coherent syntax, making it confusing for the reader and thus justifying a score of 1, as per the rubric's definition of poor language use."
#             }
#          ],
#          "critique": "{\n    \"overall_assessment\": \"The grading provided appears to be generally accurate and reflects an understanding of the criteria outlined in the rubric. However, there are areas where the critique can be made more specific and aligned with the rubric's detailed descriptions.\",\n    \"category_critiques\": [\n        {\n            \"category\": \"Position Clarity\",\n            \"critique\": \"The grade of 2 is appropriate here as the justification clearly notes that the position taken is somewhat clear but lacks focus and is confusing, which aligns with the rubric's description for a score of 2. However, the critique could benefit from specific examples of where the position is unclear to provide more targeted feedback.\"\n        },\n        {\n            \"category\": \"Supporting Arguments\",\n            \"critique\": \"The grade of 3 matches the rubric's criteria for providing some supporting arguments with minimal elaboration. This is adequately reflected in the justification. Additional examples of arguments that are broad and lack details could strengthen the critique.\"\n        },\n        {\n            \"category\": \"Organization and Structure\",\n            \"critique\": \"The justification aligns well with a score of 2, as it points out the disjointed ideas and abrupt transitions. This fits the rubric's description of weak organization. The feedback could be improved by suggesting specific structural changes such as clearer topic sentences or better transitions.\"\n        },\n        {\n            \"category\": \"Engagement and Audience Awareness\",\n            \"critique\": \"The score of 3 is justified, indicating a basic level of engagement. The critique notes the effort to engage readers but mentions disruptions due to grammatical errors and awkward phrasing. Providing specific examples of engaging sentences versus awkward ones could clarify this feedback further.\"\n        },\n        {\n            \"category\": \"Language and Style\",\n            \"critique\": \"The score of 1 is appropriate given the extensive grammatical, syntactical, and vocabulary errors noted in the justification. The critique effectively identifies specific language issues, which aligns well with the rubric's definition of poor language use.\"\n        }\n    ],\n    \"potential_biases\": [\n        \"Potential subjectivity in evaluating language errors as more significant than they are.\",\n        \"Possible bias towards expecting a high level of detail in supporting arguments, which may not align with the expectations for this level.\"\n    ],\n    \"suggestions_for_improvement\": [\n        \"Provide specific examples from the text to illustrate points where the position clarity is lacking.\",\n        \"Offer constructive suggestions for how to enhance the organization and structure, such as clear topic sentences and logical flow of ideas.\",\n        \"Highlight parts of the text that effectively engage the reader and contrast them with sections that need improvement to offer clear guidance.\",\n        \"Recommend focused language exercises or resources to improve grammar and syntax.\"\n    ]\n}"
#       },
#       "status": "pending",
#       "created_at": "2024-07-08T14:52:48.291553Z",
#       "updated_at": "2024-07-08T14:52:48.291553Z",
#       "approved_by": null,
#       "approved_at": null,
#       "human_approved": false
#    },
#    {
#       "id": 27,
#       "item_type": "grade",
#       "content": {
#          "submission_id": 82,
#          "overall_score": 0.675,
#          "category_scores": [
#             {
#                "name": "Position Clarity",
#                "score": 4,
#                "justification": "The submission's position in favor of computers making life easier and less complicated is clear and reasonably well-stated. The author supports this position with multiple points, such as the development of hand-eye coordination, the ability to learn about faraway places, and the ease of communication. However, it lacks strong emphasis and conviction in some areas, with the narrative becoming somewhat repetitive and lacking a compelling closing argument. This aligns well with the rubric definition for a score of 4, which indicates a clear and reasonably well-stated position but does not reach the highest levels of clarity or persuasiveness. Therefore, the original score of 4 is well-justified and appropriate based on the given criteria."
#             },
#             {
#                "name": "Supporting Arguments",
#                "score": 6,
#                "justification": "The submission provides fully developed and persuasive supporting arguments with specific and detailed evidence. The author supports their stance with multiple clear and relevant reasons, such as teaching hand-eye coordination, enabling communication, and providing access to information about faraway places. The examples given are not only specific but also highly relevant and effective in illustrating the points made, such as the scenario with the broken phone and the reliance on email for communication. Additionally, the inclusion of both hypothetical examples and pertinent quotes further strengthens the arguments. Overall, the thorough development and specific details within the supporting arguments justify a score of 6 for fully developed and persuasive arguments."
#             },
#             {
#                "name": "Organization and Structure",
#                "score": 3,
#                "justification": "The submission demonstrates some organization with a clear beginning, middle, and end. The basic structure is present with identifiable sections such as an introduction, body, and conclusion. However, the logical flow of ideas is somewhat lacking, with abrupt transitions between points and scattered repetition of thoughts such as the importance of hand-eye coordination and examples of travel and communication. Despite these inconsistencies, the presence of a discernible structure aligns more with a score of 3 according to the rubric, indicating minor organizational issues rather than a complete lack of logical flow."
#             },
#             {
#                "name": "Engagement and Audience Awareness",
#                "score": 3,
#                "justification": "The submission demonstrates some awareness of the audience and a basic level of engagement, which aligns with the level 3 description in the rubric. The usage of rhetorical questions and personal anecdotes shows an effort to connect with readers. Additionally, by mentioning universally relevant benefits such as enhancing hand-eye coordination and easy communication, the author attempts to relate to the audience. However, the engagement is hindered by the use of placeholder text and a lack of cohesive flow, making the narrative feel somewhat disjointed. Furthermore, the arguments made are understandable but do not deeply explore the subject matter or present it in a particularly engaging manner. Therefore, the submission does not exhibit the compelling nature required for higher levels of engagement, justifying the score of 3."
#             },
#             {
#                "name": "Language and Style",
#                "score": 2,
#                "justification": "The submission demonstrates basic language use but contains several noticeable errors in grammar, syntax, and vocabulary. For instance, awkward phrasing such as 'good hand-eye coordination is used for a lot of things; mostly everything,' and incorrect terms like 'feild' instead of 'field.' The inconsistent use of proper nouns and contractions alongside awkward sentence structures diminish clarity. While the overall style is conversational, it lacks the sophistication and polish expected at higher rubric levels. Specific issues such as these align well with a score of 2, which is characterized by basic language use with some errors."
#             }
#          ],
#          "critique": "{\n    \"overall_assessment\": \"The grading appears to be predominantly accurate with respect to the provided rubric. However, there are areas where scores and justifications could be more aligned with rubric definitions, particularly for the Organization and Structure, and Language and Style categories. The critiques are generally comprehensive and cover the necessary elements, but slight adjustments in scoring and more detailed justifications could enhance alignment with the rubric levels.\",\n    \"category_critiques\": [\n        {\n            \"category\": \"Position Clarity\",\n            \"critique\": \"The grade of 4 is justified based on the rubric. The critique correctly identifies that the position is clear and reasonably well-stated but lacks the strongest levels of conviction and persuasiveness. This aligns well with the rubric definition for a score of 4.\"\n        },\n        {\n            \"category\": \"Supporting Arguments\",\n            \"critique\": \"The score of 5 is appropriate here. The critique rightly points out that the submission provides well-developed supporting arguments with specific details. The inclusion of both hypothetical examples and relevant quotes aligns well with the score of 5, as described in the rubric.\"\n        },\n        {\n            \"category\": \"Organization and Structure\",\n            \"critique\": \"The assigned score of 2 appears to be on the lower side. Although the critique mentions weak organization and scattered ideas, there is a basic structure present in the submission. This may lean more towards a score of 3 according to the rubric, which describes some organization with a clear beginning, middle, and end but minor inconsistencies.\"\n        },\n        {\n            \"category\": \"Engagement and Audience Awareness\",\n            \"critique\": \"The score of 3 is well-justified. The critique accurately reflects the category description from the rubric, noting basic engagement and some effort to connect with the audience. While there are attempts to engage the reader, the lack of depth means it does not warrant a higher score.\"\n        },\n        {\n            \"category\": \"Language and Style\",\n            \"critique\": \"The score of 2 is appropriate given the noticeable errors in grammar, syntax, and vocabulary. The critique accurately identifies these issues, which align well with the rubric's description for a score of 2. However, there is room for a more detailed explanation of the specific language issues to strengthen the justification.\"\n        }\n    ],\n    \"potential_biases\": [\"personal bias towards stricter evaluation due to perceived repetitiveness and disorganization\", \"bias towards error identification in language use\"],\n    \"suggestions_for_improvement\": [\n        \"Consider reevaluating the Organization and Structure score to a 3 based on the presence of a basic structure with minor inconsistencies rather than a complete lack of logical flow.\",\n        \"Provide more detailed examples of language errors for the Language and Style category to strengthen the justification for the score of 2.\",\n        \"Ensure consistent alignment between scoring and the rubric definitions to avoid any potential bias towards stricter evaluations.\",\n        \"Encourage more extensive engagement and deeper connection with the audience to improve the Engagement and Audience Awareness score.\"\n    ]\n}"
#       },
#       "status": "pending",
#       "created_at": "2024-07-08T14:51:56.714756Z",
#       "updated_at": "2024-07-08T14:51:56.714756Z",
#       "approved_by": null,
#       "approved_at": null,
#       "human_approved": false
#    },
#    {
#       "id": 26,
#       "item_type": "grade",
#       "content": {
#          "submission_id": 81,
#          "overall_score": 0.425,
#          "category_scores": [
#             {
#                "name": "Position Clarity",
#                "score": 3,
#                "justification": "The submission's position that the increasing use of computers does not benefit society is apparent throughout the essay. The author provides several arguments to support this stance, including risks to safety, decreased natural education, and potential harm to social life. However, the clarity is somewhat compromised by several issues such as incomplete sentences (e.g., 'stop into'), awkward phrasing (e.g., 'keep their safety safe'), and irrelevant placeholders (e.g., '@CAPS1', '@NUM1'). While the position is evident, these grammatical errors and placeholders detract from the overall emphasis and conviction of the argument, leading to a score of 3 based on the rubric's description of a clear position that lacks emphasis and conviction."
#             },
#             {
#                "name": "Supporting Arguments",
#                "score": 3,
#                "justification": "The grade of 3 remains appropriate for the Supporting Arguments category as per the rubric. The submission does present some supporting arguments for the claim regarding the negative societal impact of computer use, focusing on safety, natural education, and social life. Scenarios like online interactions with strangers, sharing personal information on social media, and overuse of computers at the expense of family interaction are mentioned. However, the critique accurately points out that these arguments lack specific details and concrete evidence needed for higher-level scores. There are some examples provided, such as a child speaking to a potential predator and people writing about their Grand Canyon visits, but these examples are not sufficiently detailed or well-supported. Consequently, the arguments do not reach the level of being adequately or well-developed, falling short in their persuasive power. Therefore, a score of 3, which indicates 'some supporting arguments with minimal elaboration,' is fair and consistent with the rubric."
#             },
#             {
#                "name": "Organization and Structure",
#                "score": 2,
#                "justification": "The submitted work maintains a basic structure consisting of an introduction, body paragraphs, and a conclusion, which aligns with the requirements for a score of 2 in the rubric. However, the organization is notably weak as the ideas presented in the body paragraphs are scattered and do not follow a coherent flow. The transitions between distinct points (safety, nature, social life) are abrupt, leading to a lack of cohesion both within the individual paragraphs and between them. Additionally, several sentences and examples within the paragraphs are not directly supportive of the main points or stray off-topic, which contributes to a disjointed and disorganized presentation of arguments. While there is an effort to summarize the points in the conclusion, it fails to tie the arguments together cohesively, reflecting the weaknesses noted for a score of 2 in this category."
#             },
#             {
#                "name": "Engagement and Audience Awareness",
#                "score": 2,
#                "justification": "The submission demonstrates minimal awareness of the audience and limited engagement, which aligns with a score of 2 according to the rubric. While there are attempts to engage the reader through questions such as 'How would you feel?' and 'Wouldn't you rather enjoy nature in person?', these efforts are sporadic and not consistently effective. Furthermore, the structure and coherence of the arguments are weak with several grammatical errors and awkward phrasing, which disrupts the flow and makes it challenging for the reader to stay engaged. Although the attempts at reader engagement exist, they fail to form a compelling voice that connects meaningfully with the audience, warranting the score of 2."
#             },
#             {
#                "name": "Language and Style",
#                "score": 2,
#                "justification": "The submission demonstrates basic language use with some errors in grammar, syntax, and vocabulary, fitting the rubric's description for this score level. Specific issues include incorrect use of possessives, errors in verb forms, and improper sentence structures. Examples include 'ones safety' instead of 'one's safety,' and 'maybe' instead of 'may be.' There is also awkward phrasing such as 'enjoying nature is a must, in our world full of immense landscapes.' The use of placeholders like @MONTH1, @CAPS1, @PERCENT1, and @NUM1 further impacts readability and coherence. While these persistent errors and stylistic issues are significant, they are consistent with the basic language use described in the rubric level 2."
#             }
#          ],
#          "critique": "{\n    \"overall_assessment\": \"The grading generally aligns with the provided rubric criteria, although there are minor discrepancies in the justification for the scores, especially when it comes to the specificity of the supporting arguments and the structural cohesion of the essay. The grades seem fair but could benefit from more detailed critiques to guide further improvement effectively.\",\n    \"category_critiques\": [\n        {\n            \"category\": \"Position Clarity\",\n            \"critique\": \"The grade of 3 for Position Clarity is appropriate given that the position is identifiable, but the clarity is hampered by grammatical errors and logical inconsistencies. The feedback in the critique is accurate, emphasizing issues like awkward phrasing and placeholders that detract from the argument's emphasis.\"\n        },\n        {\n            \"category\": \"Supporting Arguments\",\n            \"critique\": \"The grade of 3 for Supporting Arguments is well-justified. It correctly identifies that while some supporting arguments are presented, they are not elaborated with specific details or evidence. This aligns with the rubric's description of providing 'some supporting arguments with minimal elaboration.'\"\n        },\n        {\n            \"category\": \"Organization and Structure\",\n            \"critique\": \"The grade of 2 for Organization and Structure is consistent with the feedback. The submission shows a basic structure but lacks logical flow and cohesion, which is adequately captured in the grade and the critique. Each paragraph does not effectively support the main point, leading to a disjointed overall structure.\"\n        },\n        {\n            \"category\": \"Engagement and Audience Awareness\",\n            \"critique\": \"The grade of 2 fits the evaluation for Engagement and Audience Awareness. The critique points out minimal engagement attempts and inconsistent effectiveness, which are characteristic of a score that reflects limited engagement and awareness.\"\n        },\n        {\n            \"category\": \"Language and Style\",\n            \"critique\": \"The grade of 2 in Language and Style is fitting given the noted issues such as frequent grammatical errors, basic vocabulary, and the use of irrelevant placeholders. These points accurately align with the rubric's description for this score level.\"\n        }\n    ],\n    \"potential_biases\": [\n        \"Limited examples provided for elaboration might suggest a bias towards minimal effort in argument development.\",\n        \"Frequent mention of grammatical errors could indicate a bias towards favoring grammatical accuracy over content quality.\"\n    ],\n    \"suggestions_for_improvement\": [\n        \"Provide more specific examples and concrete evidence to support the arguments for a stronger persuasive effect.\",\n        \"Work on the logical flow and cohesion between paragraphs to enhance the overall organization and structure.\",\n        \"Improve grammatical accuracy by thoroughly proofreading the text and possibly seeking external feedback before submission.\",\n        \"Increase engagement with the audience by consistently addressing the reader and maintaining a compelling voice throughout the essay.\"\n    ]\n}"
#       },
#       "status": "pending",
#       "created_at": "2024-07-08T14:51:02.336296Z",
#       "updated_at": "2024-07-08T14:51:02.336296Z",
#       "approved_by": null,
#       "approved_at": null,
#       "human_approved": false
#    },
#    {
#       "id": 25,
#       "item_type": "grade",
#       "content": {
#          "submission_id": 80,
#          "overall_score": 0.21666666666666667,
#          "category_scores": [
#             {
#                "name": "Position Clarity",
#                "score": 1,
#                "justification": "The submission suggests that computers have a negative effect on daily life. However, this position is unclear and lacks specificity, making it ambiguous for the reader. The writing is disjointed and difficult to follow, compounded by numerous grammatical and spelling errors that further obscure the intended message. The main position is fragmented and not clearly communicated, aligning with the rubric's level 1 description: 'Takes a position but it is unclear or ambiguous.' Therefore, the score of 1 is appropriate based on the rubric's criteria."
#             },
#             {
#                "name": "Supporting Arguments",
#                "score": 2,
#                "justification": "The submission does mention arguments against computer usage, such as the lack of physical activity, potential physical harm, and privacy issues. However, these arguments are mentioned in a general and vague manner without specific details or concrete evidence to support them. For example, the term 'ardthritis' is used inaccurately, which not only distracts from the argument but also highlights the lack of precision and clarity. The arguments are not well-supported or thoroughly developed, fitting the rubric description for a level 2 score, which states that the submission 'provides general or vague reasons without specific details.' To improve, the submission needs to provide specific examples and concrete evidence, fully elaborating on each point made."
#             },
#             {
#                "name": "Organization and Structure",
#                "score": 1,
#                "justification": "The submission exhibits a significant lack of organization with scattered and disconnected ideas, as confirmed by the assessment and critique. Sentences transition abruptly between different points without any logical linkage, leading to a confusing overall structure. The document lacks a clear beginning, middle, or end, severely impacting the reader\u2019s ability to follow the argument. Additionally, numerous grammatical errors and placeholders further disrupt the presentation and flow. These critical issues align closely with the rubric's level 1 description, justifying the score of 1."
#             },
#             {
#                "name": "Engagement and Audience Awareness",
#                "score": 1,
#                "justification": "The justification for the original score of 1 is well-founded, as the submission shows no awareness of the audience. The reader is not engaged due to numerous grammatical errors and spelling mistakes, which detract from coherence and structure. The use of placeholders like @NUM1 and @CAPS1 further disrupts the reading experience. The message lacks clarity and focus, making it difficult for the reader to follow or stay interested. Therefore, the submission does not meet the criteria for higher levels of engagement and audience awareness according to the rubric, affirming the appropriate score of 1."
#             },
#             {
#                "name": "Language and Style",
#                "score": 1,
#                "justification": "The submission demonstrates significant issues in language use, with pervasive errors in grammar, syntax, and vocabulary that starkly align with the rubric's description for a score of 1. Specific errors include the misuse of words like 'affect' instead of 'effect' and 'acess' instead of 'access,' along with numerous incorrect verb forms (e.g., 'cant exercise are wasting many are have the posibility'). Awkward syntax and misapplied or missing punctuation further impede readability and comprehension. The text is riddled with spelling mistakes and misused words, making it difficult to follow. Overall, these language issues critically impair the clarity and coherence of the text, justifying a score of 1 according to the rubric."
#             }
#          ],
#          "critique": "{\n    \"overall_assessment\": \"The grading assessment aligns well with the provided rubric. Each category identifies specific shortcomings and elaborates on how they correspond to the rubric's scoring levels. The grades given are justified with clear explanations that highlight the weaknesses in the submission.\",\n    \"category_critiques\": [\n        {\n            \"category\": \"Position Clarity\",\n            \"critique\": \"The assessment accurately identifies that the submission's position on the impact of computers is unclear and disjointed. The justification specifies the ambiguity and grammatical issues that obscure the intended message, appropriately aligning with the rubric's description for a score of 1.\"\n        },\n        {\n            \"category\": \"Supporting Arguments\",\n            \"critique\": \"The score of 2 is justified considering the arguments are mentioned but lack depth and specific details. The critique could be enhanced by pinpointing exact examples where the arguments are vague and how they fail to provide substantial support for the main position.\"\n        },\n        {\n            \"category\": \"Organization and Structure\",\n            \"critique\": \"The assessment correctly identifies the lack of organization, noting that ideas are scattered and disconnected. The critique is well-aligned with the rubric's level 1 description and clearly illustrates why the score of 1 is appropriate.\"\n        },\n        {\n            \"category\": \"Engagement and Audience Awareness\",\n            \"critique\": \"The critique effectively highlights the submission's failure to engage the reader, supported by examples of grammatical errors and placeholders disrupting reader engagement. The score of 1 is well-justified based on the rubric.\"\n        },\n        {\n            \"category\": \"Language and Style\",\n            \"critique\": \"The assessment is thorough in highlighting the frequent errors in grammar, syntax, and vocabulary, and provides specific examples of these errors. The score of 1 fits well with the rubric's description, as the pervasive issues in language use severely impact clarity and coherence.\"\n        }\n    ],\n    \"potential_biases\": [\n        \"There may be a predisposition to assign lower scores due to the focus on identifying errors rather than recognizing any strengths in the submission.\"\n    ],\n    \"suggestions_for_improvement\": [\n        \"Provide concrete examples from the submission when critiquing supporting arguments to illustrate the points of vagueness or lack of detail.\",\n        \"Consider balancing critiques by identifying any strengths or partial successes within the submission, even if minimal, to provide a holistic view of the work.\",\n        \"Encourage suggestions for improving the clarity of the position and coherence of arguments to guide future improvements.\"\n    ]\n}"
#       },
#       "status": "pending",
#       "created_at": "2024-07-08T14:50:11.281993Z",
#       "updated_at": "2024-07-08T14:50:11.281993Z",
#       "approved_by": null,
#       "approved_at": null,
#       "human_approved": false
#    },
#    {
#       "id": 24,
#       "item_type": "grade",
#       "content": {
#          "submission_id": 79,
#          "overall_score": 0.49166666666666664,
#          "category_scores": [
#             {
#                "name": "Position Clarity",
#                "score": 3,
#                "justification": "The submission articulates a clear position that computers have a positive effect, highlighting benefits such as family connection, education, and convenience. This aligns with the rubric\u2019s description for a score of 3 as the position is discernible but lacks the necessary emphasis and conviction. The argument is weakened by repetitive points, inadequate transitions, and grammatical errors, which detract from the clarity and coherence. Enhancing the structure, strengthening the transitions, and refining the language would make the position more compelling and elevate the overall quality of the submission."
#             },
#             {
#                "name": "Supporting Arguments",
#                "score": 4,
#                "justification": "The submission provides several supporting arguments regarding the positive effects of computers on families, education, and convenience. Specific examples are included, such as connecting with family via email, finding board games online, retrieving activity information, and accessing educational resources. These arguments are relatively well-developed, mixing general and specific details. However, they lack some elaboration and depth. In particular, the points about convenience and education could be further expanded with more detailed evidence and clearer connections to the main argument. This aligns well with the rubric\u2019s criteria for a score of 4, which indicates adequate supporting arguments with a mix of general and specific details."
#             },
#             {
#                "name": "Organization and Structure",
#                "score": 3,
#                "justification": "The submission demonstrates some organization with a clear beginning, middle, and end. The writer presents three primary reasons for the positive effect of computers\u2014connecting families, enhancing education, and offering convenience. However, there are noticeable inconsistencies in the flow of ideas. Transitions between paragraphs are abrupt, and some sentences could be better structured to improve coherence. Additionally, ideas within paragraphs tend to be repetitive. These issues detract from the overall logical flow, but there is a discernible structure that goes beyond basic organization, aligning well with a score of 3 in the rubric."
#             },
#             {
#                "name": "Engagement and Audience Awareness",
#                "score": 2,
#                "justification": "The submission demonstrates minimal awareness of the audience and limited engagement, aligning with the rubric's description for a score of 2. While the writer attempts to connect with the audience by mentioning the benefits of computers, such as family connection and educational tools, the overall execution is inadequate. The presence of numerous spelling and grammatical errors further detracts from the reader\u2019s engagement. Additionally, the use of placeholders like @LOCATION1 and @NUM1 disrupts the overall coherence and professionalism of the submission. These shortcomings hinder effective audience engagement, justifying a score of 2."
#             },
#             {
#                "name": "Language and Style",
#                "score": 1,
#                "justification": "The submission demonstrates poor language use with frequent and noticeable errors in grammar, syntax, and vocabulary, which significantly impede the readability and clarity of the message. Examples such as 'computors' instead of 'computers,' 'convient' instead of 'convenient,' and 'collage' instead of 'college' illustrate the pervasive nature of these mistakes. Additionally, the presence of run-on sentences and incorrect punctuation further detracts from the readability. Misused words such as 'subssiquently' instead of 'subsequently' also hinder the effectiveness of the communication. Overall, these issues align with the rubric\u2019s criteria for the lowest score of 1, as the errors are frequent and notably undermine the quality and clarity of the submission."
#             }
#          ],
#          "critique": "{\n    \"overall_assessment\": \"The grading appears reasonable and mostly aligns with the provided rubric. However, there are some areas where the scores could be re-evaluated to more accurately reflect the descriptions in the rubric.\",\n    \"category_critiques\": [\n        {\n            \"category\": \"Position Clarity\",\n            \"critique\": \"The grade of 3 is appropriate given that the position is clear but lacks emphasis and conviction, consistent with the rubric's description for a score of 3.\"\n        },\n        {\n            \"category\": \"Supporting Arguments\",\n            \"critique\": \"The grade of 4 is consistent with the rubric\u2019s description. The submission provides adequate supporting arguments with a mix of general and specific details, yet lacks depth in certain areas, aligning well with the rubric\u2019s criteria for a score of 4.\"\n        },\n        {\n            \"category\": \"Organization and Structure\",\n            \"critique\": \"The grade of 3 accurately reflects the submission's organizational weaknesses mentioned in the justification. The structure is evident but suffers from inconsistent flow, which aligns with the rubric's criteria for a score of 3.\"\n        },\n        {\n            \"category\": \"Engagement and Audience Awareness\",\n            \"critique\": \"The grade of 2 is reasonable given the minimal audience awareness and limited engagement, compounded by spelling and grammatical errors as well as the presence of placeholders that disrupt the coherence and professionalism of the piece.\"\n        },\n        {\n            \"category\": \"Language and Style\",\n            \"critique\": \"The grade of 1 is accurate given the described frequent errors in grammar, syntax, and vocabulary. According to the rubric, these issues notably hinder the clarity and effectiveness of the message, justifying the lowest score.\"\n        }\n    ],\n    \"potential_biases\": [\n        \"Possible leniency towards the clarity of position despite grammatical errors.\",\n        \"Potential for overrating supporting arguments despite a lack of in-depth elaboration.\"\n    ],\n    \"suggestions_for_improvement\": [\n        \"Strengthen the transitions between paragraphs to improve the logical flow of ideas.\",\n        \"Expand on supporting arguments by providing more detailed and specific evidence.\",\n        \"Address grammatical errors and enhance the overall language use for better clarity and reader engagement.\",\n        \"Eliminate placeholders and review the text for coherence and professionalism.\"\n    ]\n}"
#       },
#       "status": "pending",
#       "created_at": "2024-07-08T14:49:23.624732Z",
#       "updated_at": "2024-07-08T14:49:23.624732Z",
#       "approved_by": null,
#       "approved_at": null,
#       "human_approved": false
#    },
#    {
#       "id": 23,
#       "item_type": "grade",
#       "content": {
#          "submission_id": 78,
#          "overall_score": 0.25833333333333336,
#          "category_scores": [
#             {
#                "name": "Position Clarity",
# ...
#             },
#             {
#                "name": "Organization and Structure",
#                "score": 2,
#                "justification": "The submission demonstrates weak organization. While there is a basic structure with an introduction, some supporting arguments, and a conclusion, the ideas lack logical flow. The paragraphs jump between different points without smooth transitions, causing the text to feel scattered. Additionally, there is frequent repetition and some tangential information that does not contribute cohesively to the main argument. The feedback could benefit from pointing out specific parts of the text to illustrate these issues. Overall, a score of 2 is appropriate as the text exhibits weak organization as outlined in the rubric."
#             },
#             {
#                "name": "Engagement and Audience Awareness",
#                "score": 2,
#                "justification": "The submission demonstrates minimal awareness of the audience and limited engagement, which aligns with a score of 2. The use of generalized statements and a lack of clear organization make it challenging for the reader to remain interested. The text is repetitive and somewhat disorganized, failing to effectively connect with the reader. Additionally, numerous grammatical errors and typos significantly reduce its readability and overall appeal. For instance, frequent run-on sentences and missing punctuation disrupt the flow, making it hard for the reader to follow the argument. Because of these issues, the text does not sufficiently address or engage the reader, justifying the score of 2."
#             },
#             {
#                "name": "Language and Style",
#                "score": 1,
#                "justification": "The submission contains frequent and significant errors in grammar, syntax, and vocabulary, which severely impact the clarity and readability of the text. Specific issues include misplacement of commas, improper capitalization, and subject-verb agreement errors, such as 'Computers is one of mans greatest accomplishments.' Misspellings, including 'spme' instead of 'some' and 'non' instead of 'none,' further detract from the overall quality. Moreover, the sentence structure is often confusing and awkward, evidenced by sentences like, 'I know for a fact that both of those jobs involve lots of time on time on the computer, one @MONTH1 spend more time then the other but you know exactly what @CAPS5 getting at.' These consistent language issues align with the rubric's description for a score of 1, which indicates poor language use with frequent errors."
#             }
#          ],
#          "critique": "{\n    \"overall_assessment\": \"The grading appears to be largely accurate according to the provided rubric, though there are a few areas where it could be refined to better match the rubric's descriptions. The feedback is generally constructive and identifies specific weaknesses in the submission, such as lack of depth in arguments and weak organizational structure. However, there are some areas where the feedback could be more detailed to further justify the scores given.\",\n    \"category_critiques\": [\n        {\n            \"category\": \"Position Clarity\",\n            \"critique\": \"The score of 3 seems appropriate based on the justification provided. The critique notes that the position is clear but lacks emphasis and conviction, which aligns well with the rubric's description for a score of 3. However, the feedback could be more specific about how the argument could be made more compelling.\"\n        },\n        {\n            \"category\": \"Supporting Arguments\",\n            \"critique\": \"The score of 3 is accurate given the rubric level description. The feedback aptly points out the lack of depth and specific details in the arguments, which matches the score level 3 that describes 'minimal elaboration.' It may have been helpful to provide examples or suggestions on how to deepen these arguments.\"\n        },\n        {\n            \"category\": \"Organization and Structure\",\n            \"critique\": \"The score of 2 is well-justified by the critique. The feedback explains that while there is a basic structure, the ideas lack logical flow and transitions are weak, aligning appropriately with the rubric level 2 description of 'weak organization.' However, more detailed examples of the disjointedness might have provided stronger support for the score.\"\n        },\n        {\n            \"category\": \"Engagement and Audience Awareness\",\n            \"critique\": \"The score of 2 matches the rubric level for 'minimal awareness and limited engagement.' The critique appropriately notes the generalized statements, lack of clear organization, and grammatical errors. While the justification is clear, additional examples of how the text fails to connect with the reader could strengthen the feedback.\"\n        },\n        {\n            \"category\": \"Language and Style\",\n            \"critique\": \"The score of 1 is justified given the frequent and significant errors in grammar, syntax, and vocabulary that the critique highlights. The specific examples of errors and awkward sentence structure strongly support the low score. No further critique needed; this category is accurately assessed.\"\n        }\n    ],\n    \"potential_biases\": [\"Lack of identified similar approved critiques makes it difficult to benchmark the appropriateness of the scores and justifications.\"],\n    \"suggestions_for_improvement\": [\n        \"Provide more specific suggestions on how the argument could be made more compelling in the 'Position Clarity' category.\",\n        \"Identify specific parts of the text where the arguments could be deepened for more effective feedback under 'Supporting Arguments'.\",\n        \"Offer concrete examples of parts of the text that lack logical flow or have disjointed transitions in the 'Organization and Structure' category.\",\n        \"Provide additional examples and suggestions for how the text could better engage the reader under 'Engagement and Audience Awareness'.\"\n    ]\n}"
#       },
#       "status": "pending",
#       "created_at": "2024-07-08T14:47:48.587353Z",
#       "updated_at": "2024-07-08T14:47:48.587353Z",
#       "approved_by": null,
#       "approved_at": null,
#       "human_approved": false
#    },
#    {
#       "id": 21,
#       "item_type": "grade",
#       "content": {
#          "submission_id": 76,
#          "overall_score": 0.36666666666666664,
#          "category_scores": [
#             {
#                "name": "Position Clarity",
#                "score": 2,
#                "justification": "The submission takes a position in favor of using computers and highlights several benefits such as communication, access to information, and job-related tasks. However, the position is somewhat clear but lacks focus and is stated in a somewhat confusing manner. The argument is disjointed and not well-organized, making it difficult to consistently follow the main point throughout the essay. Specific phrases and ideas are repetitive, and numerous grammatical and spelling errors further obscure the clarity of the position. This aligns with the rubric's description for a level 2 score, which states that the position is somewhat clear but may lack focus or be stated in a confusing manner. To improve this score, the position should be more focused and clearly stated, with a coherent and organized argument throughout the essay."
#             },
#             {
#                "name": "Supporting Arguments",
#                "score": 3,
#                "justification": "The submission includes some supporting arguments for the benefits of using computers, such as social connectivity, finding information, and assisting with job-related tasks. However, these arguments are only minimally elaborated upon. The benefits mentioned are not backed up with detailed evidence or specific examples, which limits their effectiveness. The overall arguments are fragmented and lack depth, reducing their persuasive power. Therefore, based on the rubric, this submission aligns most closely with the level that 'provides some supporting arguments with minimal elaboration.' To improve this score, providing detailed evidence and more comprehensive arguments would be beneficial."
#             },
#             {
#                "name": "Organization and Structure",
#                "score": 2,
#                "justification": "The submission demonstrates a basic structure with a clear beginning, middle, and end, aligning with the rubric level 2 description. However, it suffers from weak organization due to a lack of logical flow between ideas. The points presented are scattered and often repetitive. While there are attempts to group similar ideas together, the transitions between sentences and paragraphs are weak, causing the text to feel disjointed. Additionally, the inclusion of tangentially related information without clear connections between ideas further weakens the overall organization. To improve, stronger transitions and a more logical progression of ideas are needed."
#             },
#             {
#                "name": "Engagement and Audience Awareness",
#                "score": 2,
#                "justification": "The score of 2 is appropriate based on the provided critique and the rubric descriptions. The submission demonstrates minimal awareness of the audience and limited engagement. Although personal anecdotes and basic benefits of computers are included, the overall engagement is significantly impacted by the use of placeholders (e.g., @NUM1, @MONTH1), which disrupts the flow and coherence. Additionally, multiple spelling and grammatical errors further reduce reader engagement. There is an attempt to address common concerns and benefits of computers, but the lack of refinement and coherence keeps the engagement at a minimal level. To improve this score, the draft should be refined to better address the audience more effectively, remove placeholders, and minimize errors."
#             },
#             {
#                "name": "Language and Style",
#                "score": 1,
#                "justification": "The score of 1 aligns with the provided rubric for Language and Style, where the description for level 1 is characterized by poor language use with frequent errors in grammar, syntax, and vocabulary. The submission contains a significant number of errors, including incorrect spelling ('coordibates' instead of 'coordinates', 'mysace' instead of 'Myspace'), incorrect verb forms ('able ourselfs'), awkward phrases ('talking and becoming friends will others'), and incorrect usage of articles and pronouns. These issues severely impact the overall readability and coherence of the text, making it difficult to follow and understand. To improve this score, significant proofreading and editing are necessary to correct these frequent language errors and enhance the overall language quality."
#             }
#          ],
#          "critique": "{\n    \"overall_assessment\": \"The provided grades appear to be generally accurate when evaluated against the rubric. Each category's score is justified adequately based on the criteria specified, and the reasoning aligns with the descriptions provided in the rubric. However, there are areas for nuanced feedback and suggestions for improvement to offer a more rounded evaluation.\",\n    \"category_critiques\": [\n        {\n            \"category\": \"Position Clarity\",\n            \"critique\": \"The score of 2 is fitting based on the provided justification. The position is identified but lacks clarity and is disorganized. The justification aligns well with the rubric description for a level 2 score. A more focused argument could improve this score.\"\n        },\n        {\n            \"category\": \"Supporting Arguments\",\n            \"critique\": \"The score of 3 is appropriate as the submission includes several supporting arguments, though they lack depth and specific details. The minimal elaboration on benefits aligns with the rubric levels accurately. To increase the score, providing detailed evidence and more comprehensive arguments would be beneficial.\"\n        },\n        {\n            \"category\": \"Organization and Structure\",\n            \"critique\": \"A score of 2 is justified given the weak organization and logical flow of ideas. The presence of a basic structure but lack of coherence matches the level 2 rubric description. Strengthening transitions and ensuring each paragraph logically connects would help raise this score.\"\n        },\n        {\n            \"category\": \"Engagement and Audience Awareness\",\n            \"critique\": \"The score of 2 is appropriate as the submission shows minimal audience awareness and limited engagement. The use of placeholders and multiple errors hinder the readability and engagement level. Refining the draft to address common concerns more effectively and reducing errors could improve this category.\"\n        },\n        {\n            \"category\": \"Language and Style\",\n            \"critique\": \"The score of 1 is clearly justified by the significant number of language issues. Frequent grammar, syntax, and vocabulary errors heavily impact readability, aligning with the rubric level 1 description. Proofreading and editing to correct these errors are essential to improve this score.\"\n        }\n    ],\n    \"potential_biases\": [\n        \"The evaluation might be influenced by the presence of numerous spelling and grammatical errors, potentially overshadowing the content quality.\",\n        \"A lack of detailed examples may lead to a more harsh critique in supporting arguments than warranted.\"\n    ],\n    \"suggestions_for_improvement\": [\n        \"Refine the clarity of position by focusing on a central argument and ensuring it is clearly stated.\",\n        \"Elaborate on supporting arguments with specific examples and detailed evidence to strengthen the persuasive power.\",\n        \"Improve organization and structure by employing clear transitions and logical flow between paragraphs.\",\n        \"Enhance engagement by removing placeholders, addressing the audience more directly, and minimizing errors.\",\n        \"Significant proofreading to correct frequent language errors and improving overall language quality.\"\n    ]\n}"
#       },
#       "status": "pending",
#       "created_at": "2024-07-08T14:46:59.727897Z",
#       "updated_at": "2024-07-08T14:46:59.727897Z",
#       "approved_by": null,
#       "approved_at": null,
#       "human_approved": false
#    }
# ]
#
# Summary Statistics:
#        Submission ID  Rater1 Grade  Rater2 Grade  System Grade
# count       10.00000     10.000000     10.000000     10.000000
# mean        79.50000      4.500000      4.300000      0.393333
# std          3.02765      0.527046      0.674949      0.125696
# min         75.00000      4.000000      3.000000      0.216667
# 25%         77.25000      4.000000      4.000000      0.360417
# 50%         79.50000      4.500000      4.000000      0.375000
# 75%         81.75000      5.000000      5.000000      0.416667
# max         84.00000      5.000000      5.000000      0.675000
#
# Percentage of null values:
# Submission ID    0.0
# Rater1 Grade     0.0
# Rater2 Grade     0.0
# System Grade     0.0
# dtype: float64

# %%
try:
    df = pd.read_csv('data/asap-aes/test_set.tsv', sep='\t', encoding='ISO-8859-1')
    print("File loaded successfully")
except FileNotFoundError:
    print("File not found. Please check the file path.")
except pd.errors.ParserError:
    print("Error parsing the file. Please check the file format.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File loaded successfully

# %%
df
# Out:
#       essay_id  essay_set                                              essay  \
# 0         2383          1  I believe that computers have a positive effec...
# 1         2384          1  Dear @CAPS1, I know some problems have came up...
# 2         2385          1  Dear to whom it @MONTH1 concern, Computers are...
# 3         2386          1  Dear @CAPS1 @CAPS2, @CAPS3 has come to my atte...
# 4         2387          1  Dear Local newspaper, I think that people have...
# ...        ...        ...                                                ...
# 4249     22238          8  Just One @CAPS1 @CAPS2 can bring people togeth...
# 4250     22239          8   @CAPS8 Was my first time going to the band ca...
# 4251     22240          8  Laughter is one of the most important things i...
# 4252     22241          8                                  A @CAPS1 Of @C...
# 4253     22242          8    Good @CAPS1 In @LOCATION1.  Every year a sel...
#
#       domain1_predictionid  domain2_predictionid
# 0                     2383                   NaN
# 1                     2384                   NaN
# 2                     2385                   NaN
# 3                     2386                   NaN
# 4                     2387                   NaN
# ...                    ...                   ...
# 4249                 25238                   NaN
# 4250                 25239                   NaN
# 4251                 25240                   NaN
# 4252                 25241                   NaN
# 4253                 25242                   NaN
#
# [4254 rows x 5 columns]
